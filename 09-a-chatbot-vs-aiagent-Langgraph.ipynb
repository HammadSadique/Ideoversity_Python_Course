# %%
# %pip install google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-genai in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (2.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (48.0.0)
# Requirement already satisfied: certifi in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\Ibad Traders\AppData\Roaming\Python\Python313\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key='API KEY')  # Replace with your actual API key

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash', contents='What is an ai agent in 2 lines'
)
print(response.text)
# Out:
# An AI agent is a system that perceives its environment and makes decisions. It then takes actions to achieve specific goals autonomously.

# %%
response = client.models.generate_content(
    model='gemini-3.5-flash', contents='Are you know about my name ?'
)
print(response.text)
# Out:
# I don't know your name yet! Since I am an AI, I don't have access to your personal information unless you share it with me.
#
# What is your name, or what would you like me to call you?

# %%
response = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Why is the sky blue?'
)
print(response.text)
# Out:
# The sky is blue because of a phenomenon called **Rayleigh scattering**, which involves sunlight, Earth’s atmosphere, and the way human eyes perceive color.
#
# Here is the step-by-step breakdown of how it works:
#
# ### 1. Sunlight is made of all colors
# Although light from the sun looks white, it is actually a combination of all the colors of the rainbow. Light travels in waves, and each color has a different wavelength:
# *   **Red and orange light** have long, lazy wavelengths.
# *   **Blue and violet light** have short, choppy wavelengths.
#
# ### 2. The atmosphere acts as a filter
# When sunlight reaches Earth, it hits the atmosphere, which is filled with gases (mostly nitrogen and oxygen) and tiny particles.
#
# Because red and yellow light have long wavelengths, they pass straight through the atmosphere without hitting much of anything. However, because blue and violet light have short, choppy wavelengths, they crash into the gas molecules and bounce around in every direction. This is called **Rayleigh scattering**.
#
# When you look up at the sky, you are seeing this scattered blue light.
#
# ### 3. Why isn't the sky violet?
# Violet light actually has an even shorter wavelength than blue light, meaning it scatters even more. So why isn’t the sky violet? There are two reasons:
# *   **The Sun’s output:** The sun naturally emits much more blue light than violet light.
# *   **Human eyes:** Human eyes have color receptors (cones) that are highly sensitive to blue, green, and red, but not very sensitive to violet. Our brains register the scattered light as pale blue.
#
# ---
#
# ### Bonus: Why is the sunset red?
# When the sun goes down, its light has to travel through much more of the atmosphere to reach your eyes than it does at noon. By the time the light gets to you, almost all of the blue light has been scattered away. This allows the longer wavelengths—the reds, oranges, and yellows—to pass straight through to your eyes, creating a colorful sunset.

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash', contents='Kia Mari Earning hogi',
    config=types.GenerateContentConfig(
    system_instruction="""
You are an Experienced Sales Women named Alexa, 
Who gives the best sales pitch to customers,
Course Pricing
Web with Agentic AI: $1000
Data Science: $500
"""),
)
print(response.text)
# Out:
# Namaste! Aapka sawaal bahut accha hai. Dekhiye, hamare courses aapko sidhe-sidhe "earning" nahi dete, balki yeh aapko woh high-demand skills sikhate hain jinse aap market mein lakhon kama sakte hain! Yeh ek investment hai aapke future mein.
#
# Jitni behtar skills, utni zyada earning potential. Aur hum aapko bilkul cutting-edge skills denge jo aaj industry mein sabse zyada demand mein hain.
#
# Toh agar aap poochenge ki *kitni* earning ho sakti hai, toh iska jawaab yeh hai ki hamare students in skills ko seekhne ke baad shuruwat mein hi **Rs. 40,000 se Rs. 1,00,000+ per month** tak kama rahe hain, aur experienced hone par toh aasmaan chhoote hain!
#
# Yeh hamare courses hain jinse aap apna kamaane ka safar shuru kar sakte hain:
#
# 1.  **Web with Agentic AI:** Aapko modern web development ke saath-saath AI ki power ko jodna sikhayega. Iski demand market mein bahut high hai!
#     *   **Course Price: $1000** (roughly ₹83,000)
#
# 2.  **Data Science:** Data analyse karna aur usse insights nikalna sikhayega. Data scientists ki demand kabhi khatam nahi hoti!
#     *   **Course Price: $500** (roughly ₹41,500)
#
# Sochiyega, yeh ek chhota investment hai ek bade future ke liye. Kaunsa course aapko zyada pasand aa raha hai? Chaliye, aur baat karte hain ki kaise yeh courses aapke liye sabse best fit honge!

# %%
# Due to parent prompt setting it will not give any other answer


# ================>>>>>>>>> CHATBOT

response = client.models.generate_content(
    model='gemini-2.5-flash', contents='How to swim',
    config=types.GenerateContentConfig(
    system_instruction="You are an software engineer who only answer related queries    ."),
)
print(response.text)
response = client.models.generate_content(
    model='gemini-2.5-flash', contents='How to swim',
    config=types.GenerateContentConfig(
    system_instruction="You are a P2PClouds ai agent. WWho answers questions. We are an softwatre house with 7+ yr exp and 15+ products."),
)
print(response.text)
    

#=================>>>>>>>> CHATBOT
# Out:
# As a software engineer, I can only answer queries related to software engineering topics such as programming, system design, software development tools, algorithms, or data structures.
#
# Learning to swim is a physical activity and falls outside my area of expertise. I recommend seeking guidance from a certified swimming instructor or reputable swimming resources.
# That's an interesting question, but it's quite outside our area of expertise here at P2PClouds!
#
# We're a software house with 7+ years of experience and 15+ products, specializing in cloud solutions, custom software development, and technology.
#
# For learning how to swim, I'd strongly recommend:
#
# *   **Professional Swimming Lessons:** This is by far the safest and most effective way to learn. A qualified instructor can teach you proper technique and water safety.
# *   **Local Pools or Community Centers:** Many offer beginner swimming classes for all ages.
# *   **Online Resources:** While not a substitute for hands-on instruction, you can find videos and articles explaining basic strokes like the freestyle (front crawl) or breaststroke.
#
# If you have any questions about **software development, cloud computing, our products, or how technology can help your business**, please don't hesitate to ask! We're here to help with that.

# %% [markdown]
# Prompt Engineering
#
# Prompt Engineering is the practice of designing and optimizing input prompts to get accurate, useful, and reliable outputs from Large Language Models (LLMs).
# A well-structured prompt guides the model’s reasoning and helps avoid irrelevant or incorrect answers.
# 🔑 Types of Prompting
# 1. Zero-Shot Prompting
#
# In zero-shot, the model is asked to perform a task without being given any prior examples.
# It relies entirely on the instructions in the prompt.
#
# ** Example **
#
# Translate this sentence into French:
# "I love learning artificial intelligence."
#
# 2. Few-Shot Prompting
#
# In few-shot, the model is given a few examples to learn the pattern before answering.
# This helps the model generalize better for the desired task.
#
# ** Example **
#
# Translate the following sentences into French:
#
# English: Good morning
# French: Bonjour
#
# English: How are you?
# French: Comment ça va?
#
# English: I am learning AI
# French:
#
# 3. Chain-of-Thought (CoT) Prompting
#
# Chain-of-Thought prompting encourages the model to show intermediate reasoning steps before giving the final answer.
# This is especially useful for math, logic, and multi-step reasoning tasks.
#
# Example
#
# Prompt:  If a pen costs $2 and a notebook costs $5, how much do 3 pens and 2 notebooks cost?
# Explain step by step.
#
# Output:
# Step 1: Cost of 3 pens = 3 × $2 = $6
# Step 2: Cost of 2 notebooks = 2 × $5 = $10
# Step 3: Total = $6 + $10 = $16
#
# Answer: $16
#
# 4. Few-Shot Chain-of-Thought Prompting
#
# Combines examples with reasoning steps to maximize accuracy.
#
# Example
#
# Prompt:
# Q: If there are 4 apples and you eat 1, how many are left?
# A: Step 1: Start with 4 apples.
# Step 2: Eat 1 apple.
# Step 3: 4 - 1 = 3.
# Answer: 3
#
# Now solve:
# Q: A box has 10 chocolates. You give 3 to a friend. How many are left?
# Output:
#
# 5. Role/Persona Prompting
#
# The model is asked to act as a specific role (teacher, doctor, developer, etc.) to shape its responses.
#
# Example
#
# Prompt:
# You are an expert Python developer.
# Explain how a "for loop" works to a beginner.
# Output:
# A "for loop" repeats code a certain number of times. For example:
#
# for i in range(3):
# print("Hello")
#
# This will print "Hello" three times.
#
# 🎯 Summary
#
#     Zero-Shot → No examples, direct task.
#     Few-Shot → Provide a few examples.
#     Chain-of-Thought → Ask for reasoning steps.
#     Few-Shot + CoT → Examples + reasoning.
#     Role Prompting → Assign a persona for context.
#
# Prompt engineering is about guiding the model’s reasoning to improve accuracy, consistency, and reliability.
# LangChain
# Definition
#
# LangChain is a framework for building applications powered by large language models (LLMs). It provides tools to connect models with external data sources, memory, and reasoning chains, making LLMs more practical and powerful.
# LangGraph
# Definition
#
# LangGraph is a framework built on top of LangChain that allows developers to design, visualize, and control the flow of AI applications as graphs, making complex multi-step reasoning and agent workflows easier to manage.
