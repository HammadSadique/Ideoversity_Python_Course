# %% [markdown]
# # API
# ## Definition
#
# API = Application Programming Interface • Application: Software programs • Programming: Code-based communication • Interface: A bridge that connects two systems
# ## Simple Analogies
#
#     Programmatically Talking to another External System.
#
#     There are Different types of API, but at this stage you just have to call the API's
#
# ## Weather API

# %%
import requests

res=requests.get('https://p2pclouds.up.railway.app/v1/learn/weather?city=lahore')

# %%
data=res.json()

data
# Out:
# {'location': {'name': 'Lahore',
#   'region': 'Punjab',
#   'country': 'Pakistan',
#   'lat': 31.5497,
#   'lon': 74.3436,
#   'tz_id': 'Asia/Karachi',
#   'localtime_epoch': 1782031900,
#   'localtime': '2026-06-21 13:51'},
#  'current': {'last_updated_epoch': 1782031500,
#   'last_updated': '2026-06-21 13:45',
#   'temp_c': 40,
#   'temp_f': 104,
#   'is_day': 1,
#   'condition': {'text': 'Mist',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png',
#    'code': 1030},
#   'wind_mph': 5.4,
#   'wind_kph': 8.6,
#   'wind_degree': 288,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1001,
#   'pressure_in': 29.56,
#   'precip_mm': 0,
#   'precip_in': 0,
#   'humidity': 32,
#   'cloud': 50,
#   'feelslike_c': 39.9,
#   'feelslike_f': 103.8,
#   'windchill_c': 43.2,
#   'windchill_f': 109.8,
#   'heatindex_c': 44.9,
#   'heatindex_f': 112.9,
#   'dewpoint_c': 12.8,
#   'dewpoint_f': 55,
#   'vis_km': 5,
#   'vis_miles': 3,
#   'uv': 7.9,
#   'gust_mph': 6.2,
#   'gust_kph': 9.9,
#   'will_it_rain': 0,
#   'chance_of_rain': 1,
#   'will_it_snow': 0,
#   'chance_of_snow': 0}}

# %%
data['current']
# Out:
# {'last_updated_epoch': 1782031500,
#  'last_updated': '2026-06-21 13:45',
#  'temp_c': 40,
#  'temp_f': 104,
#  'is_day': 1,
#  'condition': {'text': 'Mist',
#   'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png',
#   'code': 1030},
#  'wind_mph': 5.4,
#  'wind_kph': 8.6,
#  'wind_degree': 288,
#  'wind_dir': 'WNW',
#  'pressure_mb': 1001,
#  'pressure_in': 29.56,
#  'precip_mm': 0,
#  'precip_in': 0,
#  'humidity': 32,
#  'cloud': 50,
#  'feelslike_c': 39.9,
#  'feelslike_f': 103.8,
#  'windchill_c': 43.2,
#  'windchill_f': 109.8,
#  'heatindex_c': 44.9,
#  'heatindex_f': 112.9,
#  'dewpoint_c': 12.8,
#  'dewpoint_f': 55,
#  'vis_km': 5,
#  'vis_miles': 3,
#  'uv': 7.9,
#  'gust_mph': 6.2,
#  'gust_kph': 9.9,
#  'will_it_rain': 0,
#  'chance_of_rain': 1,
#  'will_it_snow': 0,
#  'chance_of_snow': 0}

# %%
data['location']
# Out:
# {'name': 'Lahore',
#  'region': 'Punjab',
#  'country': 'Pakistan',
#  'lat': 31.5497,
#  'lon': 74.3436,
#  'tz_id': 'Asia/Karachi',
#  'localtime_epoch': 1782031900,
#  'localtime': '2026-06-21 13:51'}

# %%
ip_res=requests.get('https://ipwho.is/')

# %%
id_data=ip_res.json()

# %%
id_data

id_data['ip']
# Out:
# '103.178.79.88'
