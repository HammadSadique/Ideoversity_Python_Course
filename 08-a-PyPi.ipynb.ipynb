# %%
# %pip install pyjokes
# Out:
# Requirement already satisfied: pyjokes in c:\users\ibad traders\desktop\ideoversity\.venv\lib\site-packages (0.8.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyjokes

print(pyjokes.get_joke())
# Out:
# Why do sin and tan work? Just cos.

# %%
import pyjokes

user_input=input("Enter your mood: ")

if "joke" in user_input:
    print(pyjokes.get_joke())
else:
    print("Goodbye!")
# Out:
# Goodbye!

# %%
# %pip install spepy
# Out:
# Collecting spepy
#   Downloading spepy-1.0-py3-none-any.whl.metadata (1.3 kB)
# Downloading spepy-1.0-py3-none-any.whl (2.8 kB)
# Installing collected packages: spepy
# Successfully installed spepy-1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spepy

spepy.speak("What is your Brother Name")

# %%
# %pip install moment
# Out:
# Collecting moment
#   Downloading moment-0.12.1-py3-none-any.whl.metadata (711 bytes)
# Collecting dateparser>=0.7 (from moment)
#   Downloading dateparser-1.4.0-py3-none-any.whl.metadata (31 kB)
# Collecting pytz>=2018.9 (from moment)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting times>=0.7 (from moment)
#   Downloading times-0.7-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\ibad traders\desktop\ideoversity\.venv\lib\site-packages (from dateparser>=0.7->moment) (2.9.0.post0)
# Collecting regex>=2024.9.11 (from dateparser>=0.7->moment)
#   Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tzlocal>=0.2 (from dateparser>=0.7->moment)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ibad traders\desktop\ideoversity\.venv\lib\site-packages (from python-dateutil>=2.7.0->dateparser>=0.7->moment) (1.17.0)
# Collecting arrow (from times>=0.7->moment)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting tzdata (from tzlocal>=0.2->dateparser>=0.7->moment)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading moment-0.12.1-py3-none-any.whl (6.4 kB)
# Downloading dateparser-1.4.0-py3-none-any.whl (300 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl (277 kB)
# Downloading times-0.7-py2.py3-none-any.whl (3.8 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: pytz, tzdata, regex, tzlocal, arrow, times, dateparser, moment
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ---------- ----------------------------- 2/8 [regex]
#    ---------- ----------------------------- 2/8 [regex]
#    --------------- ------------------------ 3/8 [tzlocal]
#    --------------- ------------------------ 3/8 [tzlocal]
#    -------------------- ------------------- 4/8 [arrow]
#    -------------------- ------------------- 4/8 [arrow]
#    -------------------- ------------------- 4/8 [arrow]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ----------------------------------- ---- 7/8 [moment]
#    ---------------------------------------- 8/8 [moment]
#
# Successfully installed arrow-1.4.0 dateparser-1.4.0 moment-0.12.1 pytz-2026.2 regex-2026.5.9 times-0.7 tzdata-2026.2 tzlocal-5.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import moment
print(moment.now())
# Out:
# 2026-06-06T12:08:40+05.00

# %%
# Create a moment from a string
date=moment.date("12-18-2012")


moment.utcnow().timezone("US/Eastern").date
# Out:
# datetime.datetime(2026, 6, 6, 3, 8, 49, 83832, tzinfo=zoneinfo.ZoneInfo(key='US/Eastern'))
